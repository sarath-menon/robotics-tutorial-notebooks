# %%
using CairoMakie
using CSV
using DataFrames

# %%
tbl = (x = [1, 1, 1,2,2,2],
       height = 1:1:6,
       grp = [1, 2,  3, 1,2, 3],

       )

barplot(tbl.x, tbl.height,
        stack = tbl.grp,
        color = tbl.grp,
        axis = (xticks = (1:2, ["left", "middle"]),
                title = "Stacked bars"),
        )

# %%
using CairoMakie


f, ax, plt = pie([π/2, 2π/3, π/4],
                normalize=false,
                offset = π/2,
                color = [:orange, :purple, :green],
                axis = (autolimitaspect = 1,)
                )

f

# %% [markdown]
# # Box plot

# %%
data = CSV.read("user.csv", DataFrame)

# %%
xs = 
ys = [3
2
4
1]

dodge = rand(1:2, 4)

boxplot(xs, ys, color = :red)
