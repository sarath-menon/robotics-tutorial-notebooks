# %%
import Pkg; Pkg.activate(@__DIR__); Pkg.instantiate()

#Pkg.add("RobustAndOptimalControl");
# Out:
#   Activating project at `~/Documents/eth_courses/notebooks/control`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed LLVMExtra_jll ─────────── v0.0.21+0
#    Installed Functors ──────────────── v0.4.4
#    Installed ReverseDiff ───────────── v1.14.5
#    Installed RobustAndOptimalControl ─ v0.4.24
#    Installed GPUArrays ─────────────── v8.6.6
#    Installed LLVM ──────────────────── v5.0.0
#    Installed Optim ─────────────────── v1.7.5
#    Installed ComponentArrays ───────── v0.13.12
#     Updating `~/Documents/eth_courses/notebooks/control/Project.toml`
#   [21fd56a4] + RobustAndOptimalControl v0.4.24
#     Updating `~/Documents/eth_courses/notebooks/control/Manifest.toml`
#   [fa961155] + CEnum v0.4.2
#   [b0b7db55] + ComponentArrays v0.13.12
#   [a81e2ce2] + DescriptorSystems v1.3.7
#   [d9f16b24] + Functors v0.4.4
#   [0c68f7d7] + GPUArrays v8.6.6
#   [929cbde3] + LLVM v5.0.0
#   [0987c9cc] + MonteCarloMeasurements v1.1.4
#   [429524aa] + Optim v1.7.5
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [37e2e3b7] + ReverseDiff v1.14.5
#   [21fd56a4] + RobustAndOptimalControl v0.4.24
#   [dad2f222] + LLVMExtra_jll v0.0.21+0
# Precompiling project...
#   ✓ LLVMExtra_jll
#   ✓ Functors
#   ✓ LLVM
#   ✓ Optim
#   ✓ GPUArrays
#   ✓ ReverseDiff
#   ✓ ComponentArrays
#   ✓ RobustAndOptimalControl
#   8 dependencies successfully precompiled in 52 seconds. 252 already precompiled.

# %%
using RobustAndOptimalControl, ControlSystemsBase 
using Plots

# %%
nyquistplot(L)
#marginplot(L)

# %%
marginplot(L)

# %%
L
# Out:
# TransferFunction{Continuous, ControlSystemsBase.SisoRational{Int64}}
#           25
# ----------------------
# s^3 + 10s^2 + 10s + 10
#
# Continuous-time transfer function model

# %%
pzmap(L)

# %% [markdown]
# # Disk margins

# %%
L = tf(25, [1,10,10,10])
dm = diskmargin(L, 0)
diskmargin(L)
# Out:
# Disk margin with:
# Margin: 0.45809255114895847
# Frequency: 1.9550687804011542 rad/s,  0.3111588604854869 Hz
# Gain margins: [0.6272780282948764, 1.5941894262075302]
# Phase margin: 25.8017095639478
# Delay margin: 0.23033705465942678 s
# Skew: 0
# Worst-case perturbation: 1.1289175744397026 - 0.48311361040108963im

# %%
plot(dm)

# %% [markdown]
# ### Gain-Phase plot

# %%
gainphaseplot(L)

# %% [markdown]
# ## Nyquist exclusion disk

# %%
nyquistplot(L)
plot!(dm, nyquist=true) # plot a nyquist exclusion disk. The Nyquist curve will be tangent to this disk at `dm.ω0`
nyquistplot!(dm.f0*L, lab="perturbed") # If we perturb the system with the worst-case perturbation `f0`, the curve will pass through the critical point -1.
