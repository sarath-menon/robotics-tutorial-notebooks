# %%
import numpy as np
import matplotlib.pylab as plt
from scipy import signal as dsp
import plotter
import signals

# %% [markdown]
# ## Create noisy input signal

# %%
duration = 0.2 #s
sampling_rate = 1000 #Hz

f_true = 50 #hz
f_noise = 150 #hz
    
true_signal, t = signals.create_sin_wave(f_true, duration, sampling_rate)
noise, t = signals.create_sin_wave(f_noise, duration, sampling_rate)

noisy_signal = true_signal + noise
plt.plot(t, noisy_signal)

# %% [markdown]
# # Single pole

# %%
f_s = 1000;
f_c = 10;

f_c_normalized = 2*(f_c/f_s)

# decay value 
d = np.exp(-2*np.pi*f_c_normalized)

a = d
b = 1-d

num = [b, 0]
den = [1, -a]

filter = dsp.TransferFunction(num, den, dt = (1/f_s))

# get frequency response 
w_rad, mag_dB, phase = filter.bode() 
w_hz = w_rad/ (2*np.pi)

plotter.filter_plotter(w_hz, mag_dB, f_c, amplitude_input_unit='dB')

# %% [markdown]
# # Butterworth filter

# %% [markdown]
# ### Lowpass

# %%
f_s = 1000; # sampling frequency in Hz
m = 4; # filter order 
f_c = 100  # cutoff frequency in Hz

# design filter 
[b,a] = dsp.butter(m, f_c, fs=f_s, btype='lowpass')

# get frequency response 
w, h = dsp.freqz(b, a)
w_hz = (f_s * w)/ (2*np.pi)

mag = abs(h)

plotter.filter_plotter(w_hz, mag, f_c, amplitude_input_unit='normal')

# %%
sos = dsp.butter(m, f_c, fs=f_s, btype='lowpass', output='sos')

filtered_signal = dsp.sosfilt(sos, noisy_signal)

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(t, noisy_signal)
ax2.plot(t, filtered_signal)

ax2.set_title('After Butterworth filter')
ax2.set_xlabel('Time [seconds]')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chebyshev Type 1

# %%
f_s = 1000; # sampling frequency in Hz

rp = 3 # max ripple in dB
m = 4; # filter order 
f_c = 100  # cutoff frequency in Hz

# design filter 
b, a = dsp.cheby1(m, rp=rp, Wn=f_c, fs=f_s, btype='lowpass')

# get frequency response 
w, h = dsp.freqz(b, a)
w_hz = (f_s * w)/ (2*np.pi)

mag = abs(h)

plotter.filter_plotter(w_hz, mag, f_c, amplitude_input_unit='normal')

# %%
sos = dsp.cheby1(m, rp=rp, Wn=f_c, fs=f_s, btype='lowpass', output='sos')

filtered_signal = dsp.sosfilt(sos, noisy_signal)

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(t, noisy_signal)
ax2.plot(t, filtered_signal)

ax2.set_title('After Chebyshev 1 filter')
ax2.set_xlabel('Time [seconds]')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Elliptic

# %%
f_s = 1000; # sampling frequency in Hz

rp_pb = 1 # max ripple in passband
rp_sb = 10 # max ripple in stopband

m = 4; # filter order 
f_c = 100  # cutoff frequency in Hz

# design filter 

b, a = dsp.ellip(m, rp=rp_pb, rs=rp_sb, Wn=f_c, fs=f_s, btype='lowpass')

# get frequency response 
w, h = dsp.freqz(b, a)
w_hz = (f_s * w)/ (2*np.pi)

mag = abs(h)

plotter.filter_plotter(w_hz, mag, f_c, amplitude_input_unit='normal')

# %%
sos = dsp.ellip(m, rp=rp_pb, rs=rp_sb, Wn=f_c, fs=f_s, btype='lowpass', output='sos')

filtered_signal = dsp.sosfilt(sos, noisy_signal)

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(t, noisy_signal)
ax2.plot(t, filtered_signal)

ax2.set_title('After Elliptic filter')
ax2.set_xlabel('Time [seconds]')

plt.tight_layout()
plt.show()
