# %%
import Pkg; Pkg.activate(@__DIR__); Pkg.instantiate()

# using Pkg
# Pkg.update()
# Pkg.add("Convex")
# Pkg.add("SCS")
# Pkg.add("JuMP")
# Pkg.add("ECOS")
# Pkg.add("Plots")
# Pkg.add("LinearAlgebra")
# Pkg.add("ControlSystems")
# Out:
#   Activating project at `~/Documents/eth_courses/notebooks/optimization`
#     Updating registry at `~/.julia/registries/General.toml`
#   No Changes to `~/Documents/eth_courses/notebooks/optimization/Project.toml`
#   No Changes to `~/Documents/eth_courses/notebooks/optimization/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/Documents/eth_courses/notebooks/optimization/Project.toml`
#   No Changes to `~/Documents/eth_courses/notebooks/optimization/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/Documents/eth_courses/notebooks/optimization/Project.toml`
#   No Changes to `~/Documents/eth_courses/notebooks/optimization/Manifest.toml`
#    Resolving package versions...
#    Installed StrideArraysCore ─ v0.4.13
#    Installed Polynomials ────── v3.2.10
#     Updating `~/Documents/eth_courses/notebooks/optimization/Project.toml`
#   [a6e380b2] + ControlSystems v1.7.2
#     Updating `~/Documents/eth_courses/notebooks/optimization/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.3.1
#   [79e6a3ab] + Adapt v3.6.1
#   [ec485272] + ArnoldiMethod v0.2.0
#   [4fba245c] + ArrayInterface v7.4.3
#   [30b0a656] + ArrayInterfaceCore v0.1.29
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [2a0fbf3d] + CPUSummary v0.2.2
#   [49dc2e85] + Calculus v0.5.1
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [38540f10] + CommonSolve v0.2.3
#   [187b0558] + ConstructionBase v1.5.1
#   [a6e380b2] + ControlSystems v1.7.2
#   [aaaaaaaa] + ControlSystemsBase v1.4.2
#   [adafc99b] + CpuId v0.3.1
#   [717857b8] + DSP v0.7.8
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [bcd4f6db] + DelayDiffEq v5.42.0
#   [b429d917] + DensityInterface v0.4.0
#   [2b5f629d] + DiffEqBase v6.123.0
#   [459566f4] + DiffEqCallbacks v2.26.1
#   [b4f34e82] + Distances v0.10.8
#   [31c24e10] + Distributions v0.25.87
#   [fa6b7ba4] + DualNumbers v0.6.8
#   [4e289a0a] + EnumX v1.0.4
#   [d4d017d3] + ExponentialUtilities v1.24.0
#   [e2ba6199] + ExprTools v0.1.9
#   [7a1cc6ca] + FFTW v1.6.0
#   [7034ab61] + FastBroadcast v0.2.5
#   [9aa1b823] + FastClosures v0.3.2
#   [29a986be] + FastLapackInterface v1.2.9
#   [1a297f60] + FillArrays v1.0.0
#   [6a86dc24] + FiniteDiff v2.19.0
#   [069b7b12] + FunctionWrappers v1.1.3
#   [77dc65aa] + FunctionWrappersWrappers v0.1.3
#   [46192b85] + GPUArraysCore v0.1.4
#   [c145ed77] + GenericSchur v0.5.3
#   [86223c79] + Graphs v1.8.0
#   [3e5b6fbb] + HostCPUFeatures v0.1.14
#   [e91730f6] + Hungarian v0.7.0
#   [34004b35] + HypergeometricFunctions v0.3.15
#   [615f187c] + IfElse v0.1.1
#   [d25df0c9] + Inflate v0.1.3
#   [c8e1da08] + IterTools v1.4.0
#   [42fd0dbc] + IterativeSolvers v0.9.2
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [ef3ab10e] + KLU v0.4.0
#   [ba0b0d4f] + Krylov v0.9.0
#   [0b1a1467] + KrylovKit v0.6.0
#   [10f19ff3] + LayoutPointers v0.1.14
#   [50d2b5c4] + Lazy v0.15.1
#   [d3d80556] + LineSearches v7.2.0
#   [7a12625a] + LinearMaps v3.10.0
#   [7ed4a6bd] + LinearSolve v1.42.0
#   [bdcacae8] + LoopVectorization v0.12.157
#   [20f20a25] + MakieCore v0.6.3
#   [d125e4d3] + ManualMemory v0.1.8
#   [99c1a7ee] + MatrixEquations v2.2.9
#   [48965c70] + MatrixPencils v1.7.6
#   [46d2c3a1] + MuladdMacro v0.2.4
#   [d41bc354] + NLSolversBase v7.8.3
#   [2774e3e8] + NLsolve v4.5.1
#   [8913a72c] + NonlinearSolve v1.6.0
#   [510215fc] + Observables v0.5.4
#   [6fe1bfb0] + OffsetArrays v1.12.9
#   [1dea7af3] + OrdinaryDiffEq v6.50.0
#   [90014a1f] + PDMats v0.11.17
#   [d96e819e] + Parameters v0.12.3
#   [f517fe37] + Polyester v0.7.3
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [f27b6e38] + Polynomials v3.2.10
#   [d236fae5] + PreallocationTools v0.4.12
#   [1fd47b50] + QuadGK v2.8.2
#   [731186ca] + RecursiveArrayTools v2.38.3
#   [f2c3362d] + RecursiveFactorization v0.2.18
#   [79098fc4] + Rmath v0.7.1
#   [7e49a35a] + RuntimeGeneratedFunctions v0.5.6
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.38
#   [0bca4576] + SciMLBase v1.91.7
#   [e9a6253c] + SciMLNLSolve v0.1.4
#   [c0aeaf25] + SciMLOperators v0.2.0
#   [efcf1570] + Setfield v1.1.1
#   [727e6d20] + SimpleNonlinearSolve v0.1.14
#   [699a6c99] + SimpleTraits v0.9.4
#   [ce78b400] + SimpleUnPack v1.1.0
# ⌅ [47a9eef4] + SparseDiffTools v1.31.0
#   [e56a9233] + Sparspak v0.3.9
#   [aedffcd0] + Static v0.8.6
#   [0d7ed370] + StaticArrayInterface v1.4.0
#   [4c63d2b9] + StatsFuns v1.3.0
#   [7792a7ef] + StrideArraysCore v0.4.13
#   [2efcf032] + SymbolicIndexingInterface v0.2.2
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.10.1
#   [8290d209] + ThreadingUtilities v0.5.1
#   [d5829a12] + TriangularSolve v0.1.19
#   [410a4b4d] + Tricks v0.1.7
#   [781d530d] + TruncatedStacktraces v1.3.0
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.64
#   [19fa3120] + VertexSafeGraphs v0.2.0
#   [700de1a5] + ZygoteRules v0.2.3
#   [f5851436] + FFTW_jll v3.3.10+0
#   [f50d1b31] + Rmath_jll v0.4.0+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [1a1011a3] + SharedArrays
#   [4607b0f0] + SuiteSparse
#   [bea87d4a] + SuiteSparse_jll v5.10.1+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ StrideArraysCore
#   ✓ Polyester
#   ✓ FastBroadcast
#   ✓ TriangularSolve
#   ✓ DiffEqBase
#   ✓ Polynomials
#   ✓ SciMLNLSolve
#   ✓ DiffEqCallbacks
#   ✓ SimpleNonlinearSolve
#   ✓ MatrixPencils
#   ✓ DSP
#   ✓ RecursiveFactorization
#   ✓ ControlSystemsBase
#   ✓ LinearSolve
#   ✓ NonlinearSolve
#   ✓ OrdinaryDiffEq
#   ✓ DelayDiffEq
#   ✓ ControlSystems
#   18 dependencies successfully precompiled in 386 seconds. 247 already precompiled.

# %%
using LinearAlgebra, Plots

import Convex as cvx 
import ECOS
using Random
using ControlSystems

Random.seed!(1)
# Out:
# TaskLocalRNG()

# %% [markdown]
# ## Least Squares

# %%
# Generate random problem data
m = 4;  n = 5
A = randn(m, n); b = randn(m)

# Create a (column vector) variable of size n x 1.
x = Variable(n)

# The problem is to minimize ||Ax - b||^2 subject to x >= 0

# objective
problem = cvx.minimize(sumsquares(A * x - b))

# constrains
problem.constraints += (x >= 0)

# Solve the problem by calling solve!
solve!(problem, ECOS.Optimizer; silent_solver = true)

# Check the status of the problem
problem.status # :Optimal, :Infeasible, :Unbounded etc.

# Get the optimum value
problem.optval

# %% [markdown]
# ## Quadratic form

# %%
n = 10 
Q = randn(n,n); Q = Q'*Q + I # create PSD matrix 
q = randn(n)

A = randn(3,n)
b = randn(3)

x = cvx.Variable(n)

# NOTE: quadform(x,Q) = x'*Q*x 
cost = 0.5*cvx.quadform(x,Q) + dot(q,x) 

prob = cvx.minimize(cost)

prob.constraints += (A*x == b)

cvx.solve!(prob, ECOS.Optimizer; silent_solver = false)

xcvx = x.value::Matrix # This will always be a matrix
xcvx = vec(x.value) # convert to vector easily
# Out:
# ECOS 2.0.8 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +5.050e-02  -1.770e+01  +6e+01  4e-01  2e-01  1e+00  2e+01    ---    ---    1  2  - |  -  -
#  1  -1.611e-01  -9.488e-01  +5e+00  2e-02  1e-02  3e-01  2e+00  0.9318  3e-02   2  2  2 |  0  0
#  2  -9.053e-02  -5.021e-01  +3e+00  2e-02  9e-03  7e-01  9e-01  0.7106  4e-01   2  2  2 |  0  0
#  3  +1.372e-01  +9.362e-02  +2e-01  1e-03  6e-04  2e-02  6e-02  0.9646  3e-02   2  2  2 |  0  0
#  4  +1.473e-01  +1.433e-01  +2e-02  1e-04  5e-05  1e-03  5e-03  0.9096  3e-04   2  2  2 |  0  0
#  5  +1.471e-01  +1.461e-01  +5e-03  3e-05  1e-05  4e-04  1e-03  0.7656  4e-02   2  2  2 |  0  0
#  6  +1.469e-01  +1.467e-01  +2e-03  8e-06  4e-06  2e-04  5e-04  0.7559  1e-01   3  2  1 |  0  0
#  7  +1.470e-01  +1.470e-01  +7e-05  4e-07  2e-07  9e-06  2e-05  0.9741  2e-02   2  2  2 |  0  0
#  8  +1.470e-01  +1.470e-01  +7e-06  4e-08  2e-08  9e-07  2e-06  0.9011  1e-03   2  1  1 |  0  0
#  9  +1.470e-01  +1.470e-01  +1e-06  6e-09  3e-09  1e-07  3e-07  0.8528  2e-02   3  1  1 |  0  0
# 10  +1.470e-01  +1.470e-01  +2e-07  1e-09  7e-10  4e-08  8e-08  0.9219  2e-01   2  1  1 |  0  0
# 11  +1.470e-01  +1.470e-01  +8e-08  4e-10  2e-10  1e-08  2e-08  0.6993  4e-02   2  1  1 |  0  0
# 12  +1.470e-01  +1.470e-01  +1e-08  6e-11  3e-11  2e-09  3e-09  0.9365  7e-02   1  1  1 |  0  0
#
# OPTIMAL (within feastol=6.0e-11, reltol=6.8e-08, abstol=1.0e-08).
# Runtime: 0.000314 seconds.
# 10-element Vector{Float64}:
#   0.33743916971690374
#   0.3000951281071971
#   0.21102528613241286
#  -0.19490172865010272
#  -0.07648787610139045
#  -0.06138807405624016
#  -0.3858348483991579
#   0.19465518710571525
#  -0.0050046404648325
#  -0.06940389429198414

# %% [markdown]
# ## Convex Trajectory Optimization

# %%
function is_controllable(A,B)
    n = size(A,1)
    return rank(ctrb(A,B)) == n 
end

let 
    
    # create linear system
    nx = 4 
    nu = 2 
    A = randn(nx,nx);
    B = randn(nx,nu);
    @assert is_controllable(A,B)
    
    # time steps 
    N = 20 
    x_ic = randn(nx)
    x_g = randn(nx)
    
    # terminal cost 
    Qf = randn(nx,nx); Qf = Qf'*Qf + I # make PSD Qf 
    
    # create cvx variables x_k = X[:,k], u_k = U[:,k]
    X = cvx.Variable(nx, N)
    U = cvx.Variable(nu, N - 1)
    
    # create cost 
    cost = 0 
    for k = 1:(N-1)
        xk = X[:,k]
        uk = U[:,k]
        cost += cvx.sumsquares(xk - x_g)
        cost += norm(uk, 1)
    end
    xn = X[:,N]
    cost += 0.5*cvx.quadform(xn, Qf)
    
    # initialize cvx problem 
    prob = cvx.minimize(cost)
    
    # initial condition constraint 
    prob.constraints += X[:,1] == x_ic 
    
    for k = 1:(N-1)
        # dynamics constraints 
        prob.constraints += (X[:,k+1] == A*X[:,k] + B*U[:,k])
    end
    
    # goal constraint 
    prob.constraints += X[:,N] == x_g
    
    # norm(u)<3 
    for k = 1:(N-1)
        uk = U[:,k]
        prob.constraints += norm(uk,2) <= 3 
    end
    
    x_min = -20*ones(nx)
    x_max =  20*ones(nx)
    for k = 1:N
        xk = X[:,k]
        prob.constraints += xk <= x_max 
        prob.constraints += xk >= x_min 
    end
    
    # solve problem (silent solver tells us the output)
    cvx.solve!(prob, ECOS.Optimizer; silent_solver = false)
    
    if prob.status != cvx.MathOptInterface.OPTIMAL
        error("Convex.jl problem failed to solve for some reason")
    end
        
    # convert the solution matrices into vectors of vectors 
    X = X.value::Matrix
    U = U.value::Matrix
end
# Out:
# ECOS 2.0.8 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +0.000e+00  -3.631e+03  +4e+03  6e-02  5e-01  1e+00  1e+01    ---    ---    1  2  - |  -  -
#  1  +3.176e+01  -1.381e+03  +2e+03  2e-02  2e-01  1e+00  5e+00  0.6413  8e-02   1  1  1 |  0  0
#  2  +6.079e+01  -1.264e+03  +2e+03  2e-02  1e-01  2e+00  5e+00  0.2416  6e-01   1  1  2 |  0  0
#  3  +8.255e+01  -1.102e+03  +1e+03  2e-02  7e-02  2e+00  4e+00  0.2729  5e-01   1  1  2 |  0  0
#  4  +1.467e+02  -6.349e+02  +9e+02  1e-02  3e-02  3e+00  3e+00  0.8781  6e-01   1  1  1 |  0  0
#  5  +1.179e+02  -3.648e+02  +6e+02  7e-03  2e-02  2e+00  2e+00  0.4621  2e-01   2  1  1 |  0  0
#  6  +1.178e+02  -2.806e+02  +5e+02  6e-03  1e-02  1e+00  1e+00  0.3916  5e-01   2  2  2 |  0  0
#  7  +1.138e+02  -2.001e+02  +4e+02  4e-03  8e-03  1e+00  1e+00  0.3927  4e-01   2  2  2 |  0  0
#  8  +9.539e+01  +3.851e+00  +1e+02  1e-03  2e-03  4e-01  3e-01  0.9890  3e-01   2  1  1 |  0  0
#  9  +8.675e+01  +7.561e+01  +1e+01  2e-04  2e-04  5e-02  4e-02  0.8866  9e-03   2  1  1 |  0  0
# 10  +8.678e+01  +8.495e+01  +2e+00  3e-05  3e-05  7e-03  6e-03  0.8672  4e-02   2  1  1 |  0  0
# 11  +8.676e+01  +8.638e+01  +4e-01  6e-06  7e-06  2e-03  1e-03  0.8312  5e-02   2  1  1 |  0  0
# 12  +8.675e+01  +8.667e+01  +1e-01  1e-06  2e-06  3e-04  3e-04  0.8244  5e-02   2  1  1 |  0  0
# 13  +8.675e+01  +8.672e+01  +4e-02  5e-07  6e-07  1e-04  1e-04  0.9023  3e-01   2  1  1 |  0  0
# 14  +8.675e+01  +8.675e+01  +2e-03  3e-08  3e-08  7e-06  6e-06  0.9472  4e-03   2  1  1 |  0  0
# 15  +8.675e+01  +8.675e+01  +1e-04  2e-09  2e-09  5e-07  4e-07  0.9381  8e-03   2  1  1 |  0  0
# 16  +8.675e+01  +8.675e+01  +7e-06  9e-11  1e-10  2e-08  2e-08  0.9890  4e-02   3  1  1 |  0  0
# 17  +8.675e+01  +8.675e+01  +9e-08  2e-12  2e-12  3e-10  3e-10  0.9869  1e-04   2  1  1 |  0  0
#
# OPTIMAL (within feastol=2.1e-12, reltol=1.1e-09, abstol=9.2e-08).
# Runtime: 0.003690 seconds.
# 2×19 Matrix{Float64}:
#  -3.01176e-9  -2.87701e-10  -4.38317e-10  …  -3.48157e-13  -4.06267e-10
#   0.788816     0.0250292    -0.0684618       -0.160314      0.141862
